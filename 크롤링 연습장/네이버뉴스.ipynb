# %% [markdown]
# ## 뉴스 크롤링하기

# %% [markdown]
# ### 하루 최대 20개의 기사만 크롤링하여 CSV 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui
import csv
from datetime import datetime, timedelta
import time

keyword = pyautogui.prompt("검색어를 입력하세요")
start_date = pyautogui.prompt("시작 날짜 (예: 2023-08-10): ")
end_date = pyautogui.prompt("종료 날짜 (예: 2023-08-13): ")
current_date = datetime.strptime(start_date, "%Y-%m-%d")

with open(f"{keyword}_result.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(['Date', 'URL', 'Title', 'Contents'])
    
    while current_date <= datetime.strptime(end_date, "%Y-%m-%d"):
        print(f"{current_date.strftime('%Y-%m-%d')} 크롤링 중...")
        
        count_for_day = 0
        
        for i in range(1, 201, 10):  # 하루에 최대 20개 기사를 크롤링하기 위해 범위 설정
            if count_for_day >= 20:
                break

            resp = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start={i}")
            soup = BeautifulSoup(resp.text, 'html.parser')
            articles = soup.select("div.info_group")

            for article in articles:
                if count_for_day >= 20:
                    break

                links = article.select("a.info")
                if len(links) >= 2:
                    url = links[1].attrs['href']

                    # 연예나 스포츠 뉴스 제외
                    if "entertain" in url or "sports" in url:
                        continue

                    resp = requests.get(url, headers={'User-agent': 'Mozilla/5.0'})
                    soup_sub = BeautifulSoup(resp.text, 'html.parser')
                    title = soup_sub.select_one(".media_end_head_title")
                    contents = soup_sub.select_one('#dic_area')

                    if title and contents:
                        writer.writerow([current_date.strftime('%Y-%m-%d'), url, title.text.strip(), contents.text.strip()])
                        count_for_day += 1
                        time.sleep(0.4)

        current_date += timedelta(days=1)
# Out:
# 2023-06-01 크롤링 중...
# 2023-06-02 크롤링 중...
# 2023-06-03 크롤링 중...
# 2023-06-04 크롤링 중...
# 2023-06-05 크롤링 중...
# 2023-06-06 크롤링 중...
# 2023-06-07 크롤링 중...
# 2023-06-08 크롤링 중...
# 2023-06-09 크롤링 중...
# 2023-06-10 크롤링 중...
# 2023-06-11 크롤링 중...
# 2023-06-12 크롤링 중...
# 2023-06-13 크롤링 중...
# 2023-06-14 크롤링 중...
# 2023-06-15 크롤링 중...
# 2023-06-16 크롤링 중...
# 2023-06-17 크롤링 중...
# 2023-06-18 크롤링 중...
# 2023-06-19 크롤링 중...
# 2023-06-20 크롤링 중...
# 2023-06-21 크롤링 중...
# 2023-06-22 크롤링 중...
# 2023-06-23 크롤링 중...
# 2023-06-24 크롤링 중...
# 2023-06-25 크롤링 중...
# 2023-06-26 크롤링 중...
# 2023-06-27 크롤링 중...
# 2023-06-28 크롤링 중...
# 2023-06-29 크롤링 중...
# 2023-06-30 크롤링 중...
# 2023-07-01 크롤링 중...
# 2023-07-02 크롤링 중...
# 2023-07-03 크롤링 중...
# 2023-07-04 크롤링 중...
# 2023-07-05 크롤링 중...
# 2023-07-06 크롤링 중...
# 2023-07-07 크롤링 중...
# 2023-07-08 크롤링 중...
# 2023-07-09 크롤링 중...
# 2023-07-10 크롤링 중...
# 2023-07-11 크롤링 중...
# 2023-07-12 크롤링 중...
# 2023-07-13 크롤링 중...
# 2023-07-14 크롤링 중...
# 2023-07-15 크롤링 중...
# 2023-07-16 크롤링 중...
# 2023-07-17 크롤링 중...
# 2023-07-18 크롤링 중...
# 2023-07-19 크롤링 중...
# 2023-07-20 크롤링 중...
# 2023-07-21 크롤링 중...
# 2023-07-22 크롤링 중...
# 2023-07-23 크롤링 중...
# 2023-07-24 크롤링 중...
# 2023-07-25 크롤링 중...
# 2023-07-26 크롤링 중...
# 2023-07-27 크롤링 중...
# 2023-07-28 크롤링 중...
# 2023-07-29 크롤링 중...
# 2023-07-30 크롤링 중...
# 2023-07-31 크롤링 중...
# 2023-08-01 크롤링 중...

# %% [markdown]
# #### 삼성전자 검색후 title, link

# %%
import requests
from bs4 import BeautifulSoup

# Protocol://Domain/Path?Parameter

resp = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90")
html = resp.text
soup = BeautifulSoup(html,'html.parser')
links = soup.select(".news_tit")
# print(links)

for link in links:
    title = link.text # 태크안에 텍스트요소 가져옴 
    url = link.attrs['href'] # href속성 가져옴
    print(title, url)
# Out:
# 삼성전자 '갤Z5·갤워치6·탭9' 시리즈 전세계 공식 출시 https://biz.sbs.co.kr/article_hub/20000131081?division=NAVER
# 삼성전자, '갤럭시 Z 플립5·폴드5' 특별한 케이스 출시 https://www.yna.co.kr/view/PYH20230811010900013?input=1196m
# 삼성전자, 갤럭시Z5 시리즈 전세계 공식 출시 https://news.kmib.co.kr/article/view.asp?arcid=0018557951&code=61141111&cp=nv
# 삼성전자, 11일 ‘갤럭시 Z 플립5·폴드5’ 등 전세계 출시 https://www.busan.com/view/busan/view.php?code=2023081109334904286
# 디아이, 삼성전자와 149억 규모 반도체 검사장비 공급계약 http://www.newsis.com/view/?id=NISX20230811_0002411213&cID=10403&pID=15000
# 삼성전자, '갤럭시 Z 플립5·폴드5' 등 신제품 전세계 출시 https://www.etnews.com/20230811000031
# 삼성전자, 갤플립5·폴드5 공식 출시…‘부산 엑스포 응원’ 케이스 눈길 https://biz.chosun.com/it-science/ict/2023/08/11/R4GW2QO7PBFA7DBHUPPASACFVI/?utm_source=naver&utm_medium=original&utm_campaign=biz
# "돌고 돌아 역시 믿을 건 삼성"…개미들 이달 삼성전자 5200억 사들여 https://www.news1.kr/articles/5137520
# 마이크로LED 늘리는 삼성전자·LG전자, 왜? https://www.bloter.net/news/articleView.html?idxno=605298
# 반도체 필독서 '칩워' 저자, 삼성전자 행사에…'깜짝 등장' [김익환의 컴퍼니... https://www.hankyung.com/finance/article/202308100486i

# %% [markdown]
# #### 검색어 입력받고 1~10 page title, link

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui
num = 1
# keyword = input('검색어를 입력하세요>>')
keyword = pyautogui.prompt('검색어를 입력하세요.')

for i in range(1,101,10):
    print(f"{num}page입니다@@@@@@@@@@@@@@@@@@@@")
    resp = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start{i}")
    html = resp.text
    soup = BeautifulSoup(html,'html.parser')
    links = soup.select(".news_tit")
# print(links)
    for link in links:
        title = link.text # 태크안에 텍스트요소 가져옴 
        url = link.attrs['href'] # href속성 가져옴
        print(title, url)
    num += 1
# Out:
# 1page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 2page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 3page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 4page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 5page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 6page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 7page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 8page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 9page입니다@@@@@@@@@@@@@@@@@@@@
# 아이브, 10월 첫 월드 투어 '쇼 왓 아이 해브' 개최 [공식] https://www.starnewskorea.com/stview.php?no=2023081114244734713
# [포토]아이브, 새만금 DIVE https://www.mk.co.kr/article/10806358
# 아이브, 美 빌보드 차트 롱런 http://sports.khan.co.kr/news/sk_index.html?art_id=202308111039003&sec_id=540301&pt=nv
# ‘아이브’ 잼버리 콘서트 뒤늦게 출연 결정…문체부 “자발적” 강조 https://www.hani.co.kr/arti/culture/culture_general/1103814.html
# 잼버리 피날레 ‘K팝 콘서트’ 막판 점검…아이브도 뜬다 https://news.kmib.co.kr/article/view.asp?arcid=0018555453&code=61121111&cp=nv
# 잼버리 4만명 'K팝 떼창'…뉴진스·아이브 등 총출동(종합2보) https://www.news1.kr/articles/5138773
# 아이브 ‘잼버리 콘서트 떼창’ [MK포토] https://www.mk.co.kr/article/10806423
# 뉴진스·아이브 따라 부르며 춤도 똑같이···우여곡절 끝 화려한 ‘K팝 피날... https://www.khan.co.kr/culture/popular_music/article/202308112022001
# 잼버리 K팝 콘서트 '아이브가 빠질 수 있나요!' [TF사진관] http://news.tf.co.kr/read/photomovie/2036415.htm
# [TD포토] 아이브 '자발적 참여한 무대' (잼버리 콘서트) http://www.tvdaily.co.kr/read.php3?aid=16917596301682742017
# 10page입니다@@@@@@@@@@@@@@@@@@@@

# %% [markdown]
# #### 네이버 뉴스 본문 크롤링
#
# 왜 네이버 뉴스만 크롤링?
# 네이버 뉴스의 본문은 전부 생김새가 동일하나 다른 뉴스들은 생김새가 달라 크롤링이 어렵다
#
# ##### 네이버 뉴스 링크 가져오는 전략
# 1. div.info_group 아래에 a.info가 2개이상인것만
# 2. 2번째 a.info의 href속성값 가져온다

# %% [markdown]
# #### 페이지내에 링크만 10개 가져올때

# %%
import requests
from bs4 import BeautifulSoup
import time
import pyautogui



resp = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90')
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
links = soup.select("div.info_group")

for link in links:
    a_tags = link.find_all('a', href=True)
    if len(a_tags) >= 2:
        url = a_tags[1]['href']
        print(url)

# %% [markdown]
# #### 본문 크롤링할때

# %%
import requests
from bs4 import BeautifulSoup
import time

resp = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90')
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
articles = soup.select("div.info_group")

for article in articles:
    links = article.select("a.info") # a tag에 클래스는 info
    if len(links) >= 2:
        url = links[1].attrs['href']
        # print(url)
        resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 각링크들 받아온후 
        html = resp.text
        soup = BeautifulSoup(html, 'html.parser')
        # print(soup)
        contents = soup.select_one('#dic_area') # dic_area: 본문 뉴스 id(#) OR newsct_body: 본문 뉴스 class(.)
        if contents:  # 결과가 있을 경우만 출력
            print(contents.text)
        time.sleep(0.5)

# %% [markdown]
# ### 검색어 입력받고, 해당 (네이버)뉴스들 출력하기

# %%
import requests
from bs4 import BeautifulSoup
import time

# 사용자로부터 검색어를 입력받습니다.
query = input("검색어를 입력하세요: ")

base_url = 'https://search.naver.com/search.naver'
params = {
    'where': 'news',
    'sm': 'tab_jum',
    'query': query
}

resp = requests.get(base_url, params=params)
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
articles = soup.select("div.info_group")

for article in articles:
    links = article.select("a.info") # a tag에 클래스는 info
    if len(links) >= 2:
        url = links[1].attrs['href']
        resp = requests.get(url, headers={'User-agent': 'Mozilla/5.0'})
        html = resp.text
        soup = BeautifulSoup(html, 'html.parser')
        print(url)
        contents = soup.select_one('#dic_area')
        if contents: 
            print(contents.text)
        time.sleep(0.5)

# %% [markdown]
# ### 1년치 타이틀 + 본문 크롤링 원할때

# %%
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta

# 사용자로부터 검색어와 날짜를 입력받습니다.
query = input("검색어를 입력하세요: ")
start_date = input("시작 날짜 (예: 2023-08-10): ")
end_date = input("종료 날짜 (예: 2023-08-13): ")

base_url = 'https://search.naver.com/search.naver'
current_date = datetime.strptime(start_date, "%Y-%m-%d")

while current_date <= datetime.strptime(end_date, "%Y-%m-%d"):
    print(f"{current_date.strftime('%Y-%m-%d')} 크롤링 중...")
    params = {
        'where': 'news',
        'sm': 'tab_jum',
        'query': query,
        'pd': '3',  # 기간 지정 검색
        'ds': current_date.strftime('%Y.%m.%d'),
        'de': current_date.strftime('%Y.%m.%d')
    }
    
    resp = requests.get(base_url, params=params)
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.select("div.info_group")
    
    for article in articles:
        links = article.select("a.info") # a tag에 클래스는 info
        if len(links) >= 2:
            url = links[1].attrs['href']
            resp = requests.get(url, headers={'User-agent': 'Mozilla/5.0'})
            html = resp.text
            soup = BeautifulSoup(html, 'html.parser')
            print(url)
            contents = soup.select_one('#dic_area')
            if contents: 
                print(contents.text)
            time.sleep(0.5)
    
    # 다음 날짜로 이동
    current_date += timedelta(days=1)

# %% [markdown]
# ### 1년치 타이틀 크롤링 하고싶을때

# %%
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta

# 사용자로부터 검색어와 날짜를 입력받습니다.
query = input("검색어를 입력하세요: ")
start_date = input("시작 날짜 (예: 2023-08-10): ")
end_date = input("종료 날짜 (예: 2023-08-13): ")

base_url = 'https://search.naver.com/search.naver'
current_date = datetime.strptime(start_date, "%Y-%m-%d")

while current_date <= datetime.strptime(end_date, "%Y-%m-%d"):
    print(f"{current_date.strftime('%Y-%m-%d')} 크롤링 중...")
    params = {
        'where': 'news',
        'sm': 'tab_jum',
        'query': query,
        'pd': '3',  # 기간 지정 검색
        'ds': current_date.strftime('%Y.%m.%d'),
        'de': current_date.strftime('%Y.%m.%d')
    }
    
    resp = requests.get(base_url, params=params)
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.select("div.info_group")
    
    for article in articles:
        links = article.select("a.info") # a tag에 클래스는 info
        if len(links) >= 2:
            url = links[1].attrs['href']
            print(url)
            time.sleep(0.5)
    
    # 다음 날짜로 이동
    current_date += timedelta(days=1)
# Out:
# 2022-08-01 크롤링 중...
# https://n.news.naver.com/mnews/article/003/0011339019?sid=101
# https://n.news.naver.com/mnews/article/421/0006251738?sid=103
# https://n.news.naver.com/mnews/article/001/0013346654?sid=101
# https://n.news.naver.com/mnews/article/008/0004777829?sid=101
# https://n.news.naver.com/mnews/article/030/0003034241?sid=103
# https://sports.news.naver.com/news.nhn?oid=311&aid=0001483354
# https://sports.news.naver.com/news.nhn?oid=005&aid=0001543705
# https://n.news.naver.com/mnews/article/001/0013348128?sid=101
# https://n.news.naver.com/mnews/article/629/0000164159?sid=103
# 2022-08-02 크롤링 중...
# https://sports.news.naver.com/news.nhn?oid=417&aid=0000838782
# https://n.news.naver.com/mnews/article/016/0002023412?sid=101
# https://n.news.naver.com/mnews/article/015/0004731858?sid=101
# https://n.news.naver.com/mnews/article/421/0006253960?sid=103
# https://n.news.naver.com/mnews/article/018/0005281810?sid=101
# https://n.news.naver.com/mnews/article/092/0002264314?sid=103
# https://sports.news.naver.com/news.nhn?oid=442&aid=0000152310
# https://sports.news.naver.com/news.nhn?oid=347&aid=0000165192
# 2022-08-03 크롤링 중...
# https://n.news.naver.com/mnews/article/003/0011342000?sid=101
# https://n.news.naver.com/mnews/article/277/0005127518?sid=103
# https://n.news.naver.com/mnews/article/079/0003671342?sid=102
# https://n.news.naver.com/mnews/article/050/0000061603?sid=101
# https://sports.news.naver.com/news.nhn?oid=442&aid=0000152352
# https://n.news.naver.com/mnews/article/119/0002626925?sid=101
# https://sports.news.naver.com/news.nhn?oid=347&aid=0000165241
# 2022-08-04 크롤링 중...
# https://n.news.naver.com/mnews/article/009/0005000515?sid=103
# https://n.news.naver.com/mnews/article/014/0004878325?sid=101
# https://n.news.naver.com/mnews/article/277/0005127943?sid=103
# https://sports.news.naver.com/news.nhn?oid=117&aid=0003632337
# https://sports.news.naver.com/news.nhn?oid=311&aid=0001484826
# https://sports.news.naver.com/news.nhn?oid=117&aid=0003632336
# 2022-08-05 크롤링 중...
# https://sports.news.naver.com/news.nhn?oid=311&aid=0001485417
# https://sports.news.naver.com/news.nhn?oid=347&aid=0000165319
# https://n.news.naver.com/mnews/article/018/0005284520?sid=101
# https://sports.news.naver.com/news.nhn?oid=442&aid=0000152426
# https://n.news.naver.com/mnews/article/396/0000620765?sid=103
# 2022-08-06 크롤링 중...
# https://sports.news.naver.com/news.nhn?oid=347&aid=0000
# https://n.news.naver.com/mnews/article/015/0004768919?sid=103
# https://n.news.naver.com/mnews/article/002/0002264354?sid=102
# https://n.news.naver.com/mnews/article/417/0000864515?sid=103
# 2022-10-30 크롤링 중...
# https://n.news.naver.com/mnews/article/009/0005037834?sid=103
# https://n.news.naver.com/mnews/article/277/0005169330?sid=104
# https://n.news.naver.com/mnews/article/009/0005037751?sid=103
# https://n.news.naver.com/mnews/article/014/0004920713?sid=101
# https://n.news.naver.com/mnews/article/020/0003459206?sid=103
# https://n.news.naver.com/mnews/article/021/0002538605?sid=104
# https://n.news.naver.com/mnews/article/001/0013541272?sid=104
# https://sports.news.naver.com/news.nhn?oid=005&aid=0001562884
# 2022-10-31 크롤링 중...
# https://n.news.naver.com/mnews/article/018/0005354449?sid=103
# https://n.news.naver.com/mnews/article/215/0001062842?sid=101
# https://n.news.naver.com/mnews/article/016/0002059352?sid=101
# https://n.news.naver.com/mnews/article/030/0003055463?sid=103
# https://n.news.naver.com/mnews/article/421/0006426504?sid=103
# https://n.news.naver.com/mnews/article/014/0004920794?sid=104
# https://n.news.naver.com/mnews/article/009/0005038171?sid=103

# %% [markdown]
# ### 연예 뉴스 크롤링하기

# %%
import requests
from bs4 import BeautifulSoup
import time

resp = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%97%90%EC%8A%A4%ED%8C%8C') # 에스파 검색링크
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
articles = soup.select("div.info_group")

for article in articles:
    links = article.select("a.info") # a tag에 클래스는 info
    if len(links) >= 2:
        url = links[1].attrs['href']
        # print(url)
        resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 각링크들 받아온후 
        html = resp.text
        soup = BeautifulSoup(html, 'html.parser')
        print(url)

        # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
        if "entertain" in resp.url:
            title = soup.select_one(".end_tit") # 연예 뉴스 타이틀 
            contents = soup.select_one("#articeBody") # 연예 뉴스 본문
        else:
            title = soup.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
            contents = soup.select_one('#dic_area') # 일반 뉴스 본문
        print("==========링크===========\n",url)
        print("==========제목===========\n",title.text.strip())
        print("==========본문===========\n",contents.text.strip())
        time.sleep(0.5) # 필수!!!!!

# %% [markdown]
# #### 스포츠뉴스는 사이트의 생김새(HTML)가 다르기때문에 오류가 난다
# ### 해결법
# - 본문 사이트 요청시 사이트 URL이 스포츠뉴스라면?
# - CSS 선택자를 바꿔준다
#
# #### if 연예뉴스 URL
#      연예뉴스 사이트의 CSS 선택자 사용
# #### elif 스포츠뉴스 URL
#      스포츠 뉴스 사이트의 CSS 선택자 사용
# #### else
#      일반 뉴스 사이트의 CSS 선택자 사용

# %%
import requests
from bs4 import BeautifulSoup
import time

resp = requests.get('https://search.naver.com/search.naver?sm=tab_hty.top&where=news&query=%EC%98%A4%EC%8A%B9%ED%99%98+&oquery=%EC%86%90%ED%9D%A5%EB%AF%BC&tqi=iL45NlprvTosshov5lVssssstdZ-295557') # 에스파 검색링크
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
articles = soup.select("div.info_group")

for article in articles:
    links = article.select("a.info") # a tag에 클래스는 info
    if len(links) >= 2:
        url = links[1].attrs['href']
        # print(url)
        resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 각링크들 받아온후 
        html = resp.text
        soup = BeautifulSoup(html, 'html.parser')
        print(url)

        # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
        if "entertain" in resp.url:
             title = soup.select_one(".end_tit") # 연예 뉴스 타이틀 
             contents = soup.select_one("#articeBody") # 연예 뉴스 본문

        elif "sports" in resp.url:
                title = soup.select_one("h4.title")
                contents = soup.select_one('#newsEndContents')

                    # contents중에서 불필요한 부분(기자명, 다른광고) div 삭제하기
                divs = contents.select('div')
                for div in divs:
                    div.decompose()  # 삭제
                paragraphs = contents.select('p')
                for p in paragraphs:
                    p.decompose()
        else:
                title = soup.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
                contents = soup.select_one('#dic_area') # 일반 뉴스 본문

        print("==========링크===========\n",url)
        print("==========제목===========\n",title.text.strip())
        print("==========본문===========\n",contents.text.strip())
        time.sleep(0.5) # 필수!!!!!

# %% [markdown]
# ### 검색어 입력받고 해당 (네이버)뉴스 본문들 출력하기

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui
keyword = pyautogui.prompt('검색어를 입력하세요.')
resp = requests.get(
    f'https://search.naver.com/search.naver?sm=tab_hty.top&where=news&query={keyword}')
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
articles = soup.select("div.info_group")

for article in articles:
    links = article.select("a.info")  # a tag에 클래스는 info
    if len(links) >= 2:
        url = links[1].attrs['href']
        # print(url)
        resp = requests.get(
            url, headers={'User-agent': 'Mozila/5.0'})  # 각링크들 받아온후
        html = resp.text
        soup = BeautifulSoup(html, 'html.parser')
        print(url)
        # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
        if "entertain" in resp.url:
             title = soup.select_one(".end_tit") # 연예 뉴스 타이틀 
             contents = soup.select_one("#articeBody") # 연예 뉴스 본문

        elif "sports" in resp.url:
                title = soup.select_one("h4.title")
                contents = soup.select_one('#newsEndContents')

                    # contents중에서 불필요한 부분(기자명, 다른광고) div 삭제하기
                divs = contents.select('div')
                for div in divs:
                    div.decompose()  # 삭제
                paragraphs = contents.select('p')
                for p in paragraphs:
                    p.decompose()
        else:
                title = soup.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
                contents = soup.select_one('#dic_area') # 일반 뉴스 본문

        print("==========링크===========\n", url)
        print("==========제목===========\n", title.text.strip())
        print("==========본문===========\n", contents.text.strip())
        time.sleep(0.5)  # 필수!!!!!

# %% [markdown]
# ### 사용자로부터 페이지 수 입력받고 그 페이지 수만큼 크롤링

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui

keyword = pyautogui.prompt("검색어를 입력하세요")
lastpage = int(pyautogui.prompt("몇 페이지까지 크롤링 할까요?")) # int변환 필요

page_num = 1
for i in range(1, lastpage * 10, 10):
    print(f"{page_num} 페이지 크롤링 중 입니다.======================================")
    resp = requests.get(f'https://search.naver.com/search.naver?sm=tab_hty.top&where=news&query={keyword}start={i}')
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.select("div.info_group")

    for article in articles:
        links = article.select("a.info") # a tag에 클래스는 info
        if len(links) >= 2:
            url = links[1].attrs['href']
            # print(url)
            resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 각링크들 받아온후 
            html = resp.text
            soup = BeautifulSoup(html, 'html.parser')
            print(url)

                       # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
            if "entertain" in resp.url:
                title = soup.select_one(".end_tit") # 연예 뉴스 타이틀 
                contents = soup.select_one("#articeBody") # 연예 뉴스 본문

            elif "sports" in resp.url:
                title = soup.select_one("h4.title")   
                contents = soup.select_one('#newsEndContents')

                    # contents중에서 불필요한 부분(기자명, 다른광고) div 삭제하기 
                divs = contents.select('div')
                for div in divs:
                    div.decompose() # 삭제
                paragraphs = contents.select('p')
                for p in paragraphs:
                    p.decompose()
            else:
                title = soup.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
                contents = soup.select_one('#dic_area') # 일반 뉴스 본문

            print("==========링크===========\n",url)
            print("==========제목===========\n",title.text.strip())
            print("==========본문===========\n",contents.text.strip())
            time.sleep(0.5) # 필수!!!!!
    page_num += 1

# %% [markdown]
# ### 워드 문서 다루기

# %%
from docx import Document

#1. 워드 생성하기 
document = Document()

#2. 워드 데이터 추가하기 
document.add_heading('기사제목', level=0)
document.add_paragraph('기사 링크')
document.add_paragraph('기사 본문')

#3. 워드 저장하기
document.save("text.docx")

# %% [markdown]
# ### 크롤링 결과를 워드파일에 저장해 보자!
# 파일 생성 위치, 데이터 입력 위치, 파일 저장 위치 고려하기

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui
from docx import Document

document = Document()

keyword = pyautogui.prompt("검색어를 입력하세요")
lastpage = int(pyautogui.prompt("몇 페이지까지 크롤링 할까요?")) # int변환 필요

page_num = 1
for i in range(1, lastpage * 10, 10):
    print(f"{page_num} 페이지 크롤링 중...")
    resp = requests.get(f'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}start={i}')
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.select("div.info_group")

    for article in articles:
        links = article.select("a.info") # a tag에 클래스는 info
        if len(links) >= 2:
            url = links[1].attrs['href']
            # print(url)
            resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 각링크들 받아온후 
            html = resp.text
            soup = BeautifulSoup(html, 'html.parser')

            # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
            if "entertain" in resp.url:
                title = soup.select_one(".end_tit") # 연예 뉴스 타이틀 
                contents = soup.select_one("#articeBody") # 연예 뉴스 본문

            elif "sports" in resp.url:
                title = soup.select_one("h4.title")   
                contents = soup.select_one('#newsEndContents')

                    # contents중에서 불필요한 부분(기자명, 다른광고) div 삭제하기 
                divs = contents.select('div')
                for div in divs:
                    div.decompose() # 삭제
                paragraphs = contents.select('p')
                for p in paragraphs:
                    p.decompose()
            else:
                title = soup.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
                contents = soup.select_one('#dic_area') # 일반 뉴스 본문

            document.add_heading(title.text.strip(), level=0)
            document.add_paragraph(url)
            document.add_paragraph(contents.text.strip())
            time.sleep(0.5) # 필수!!!!!
    page_num += 1
document.save(f"{keyword}_result.docx")
# Out:
# 1 페이지 크롤링 중...
# 2 페이지 크롤링 중...
# 3 페이지 크롤링 중...

# %% [markdown]
# ### 워드 다루기

# %%
from openpyxl import Workbook

# 엑샐 생성하기 
wb = Workbook()

# 엑셀 시트 생성하기
ws = wb.create_sheet("이도형")
ws['A1'] = '이도형'

wb.save('DHL.xlsx')

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui
from openpyxl import Workbook
from openpyxl.styles import Alignment
import time

keyword = pyautogui.prompt("검색어를 입력하세요")
lastpage = int(pyautogui.prompt("몇 페이지까지 크롤링 할까요?")) # int변환 필요

wb = Workbook()
ws = wb.create_sheet(keyword)
# 너비 설정 
ws.column_dimensions['A'].width = 60
ws.column_dimensions['B'].width = 60
ws.column_dimensions['C'].width = 120

page_num = 1
row = 1

for i in range(1, lastpage * 10, 10):
    print(f"{page_num} 페이지 크롤링 중...")
    resp = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start={i}")
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.select("div.info_group")

    for article in articles:
        links = article.select("a.info") # a tag에 클래스는 info
        if len(links) >= 2:
            url = links[1].attrs['href']
            # print(url)
            resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 에러 방지
            html = resp.text
            soup = BeautifulSoup(html, 'html.parser')

            # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
            if "entertain" in resp.url:
                title = soup.select_one(".end_tit") # 연예 뉴스 타이틀 
                contents = soup.select_one("#articeBody") # 연예 뉴스 본문

            elif "sports" in resp.url:
                title = soup.select_one("h4.title")   
                contents = soup.select_one('#newsEndContents')

                    # contents중에서 불필요한 부분(기자명, 다른광고) div 삭제하기 
                divs = contents.select('div')
                for div in divs:
                    div.decompose() # 삭제
                paragraphs = contents.select('p')
                for p in paragraphs:
                    p.decompose()
            else:
                title = soup.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
                contents = soup.select_one('#dic_area') # 일반 뉴스 본문

            ws[f'A{row}'] = url
            ws[f'B{row}'] = title.text.strip()
            ws[f'C{row}'] = contents.text.strip()
            ws[f"C{row}"].alignment = Alignment(wrap_text=True)  
            row += 1
            time.sleep(0.4)
    page_num += 1
    wb.save(f"{keyword}_result.xlsx")
# Out:
# 1 페이지 크롤링 중...
# 2 페이지 크롤링 중...

# %% [markdown]
# ### 마지막 페이지 확인하기

# %%
import requests
from bs4 import BeautifulSoup
import pyautogui
from openpyxl import Workbook
from openpyxl.styles import Alignment
import time

keyword = pyautogui.prompt("검색어를 입력하세요")
lastpage = int(pyautogui.prompt("몇 페이지까지 크롤링 할까요?")) # int변환 필요

wb = Workbook()
ws = wb.create_sheet(keyword)
# 너비 설정 
ws.column_dimensions['A'].width = 60
ws.column_dimensions['B'].width = 60
ws.column_dimensions['C'].width = 120

page_num = 1
row = 1

for i in range(1, lastpage * 10, 10):
    print(f"{page_num} 페이지 크롤링 중...")
    resp = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start={i}")
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.select("div.info_group")

    for article in articles:
        links = article.select("a.info") # a tag에 클래스는 info
        if len(links) >= 2:
            url = links[1].attrs['href']
            # print(url)
            resp = requests.get(url, headers={'User-agent': 'Mozila/5.0'}) # 에러 방지
            html = resp.text
            soup_sub = BeautifulSoup(html, 'html.parser')

            # 만약 연예 뉴스라면? redirection이 발생하므로 url이 아닌 resp.url
            if "entertain" in resp.url:
                title = soup_sub.select_one(".end_tit") # 연예 뉴스 타이틀 
                contents = soup_sub.select_one("#articeBody") # 연예 뉴스 본문

            elif "sports" in resp.url:
                title = soup_sub.select_one("h4.title")   
                contents = soup_sub.select_one('#newsEndContents')

                    # contents중에서 불필요한 부분(기자명, 다른광고) div 삭제하기 
                divs = contents.select('div')
                for div in divs:
                    div.decompose() # 삭제
                paragraphs = contents.select('p')
                for p in paragraphs:
                    p.decompose()
            else:
                title = soup_sub.select_one(".media_end_head_title") # 일반 뉴스 타이틀 
                contents = soup_sub.select_one('#dic_area') # 일반 뉴스 본문

            ws[f'A{row}'] = url
            ws[f'B{row}'] = title.text.strip()
            ws[f'C{row}'] = contents.text.strip()
            ws[f"C{row}"].alignment = Alignment(wrap_text=True)  
            row += 1
            time.sleep(0.4)

    isLastPage = soup.select_one('a.btn_next').attrs['aria-disabled']
    if isLastPage == 'true':
        print("마지막 페이지입니다.")
        break 
    page_num += 1
    wb.save(f"{keyword}_result.xlsx")
# Out:
# 1 페이지 크롤링 중...
# 2 페이지 크롤링 중...
# 3 페이지 크롤링 중...
# 마지막 페이지입니다.

# %% [markdown]
# ## 워드 클라우드
# #### 중요한 단어를 더 잘보이게 하는방법
# - 본문 내용 합치기 -> 워드클라우드 만들기

# %%
import requests
from bs4 import BeautifulSoup
import time
import pyautogui
import pyperclip

keyword = pyautogui.prompt("검색어를 입력하세요")
lastpage = int(pyautogui.prompt("몇 페이지까지 크롤링 할까요?")) # int변환 필요

page_num = 1
total_content = ""
article_num = 0

for i in range(1, lastpage * 10, 10):
    print(f"{page_num} page...")
    response = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start={i}")
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    articles = soup.select("div.info_group")

    for article in articles:
        links = article.select("a.info")
        if len(links) >= 2:
            url = links[1].attrs["href"]
            response = requests.get(url, headers={'User-agent': 'Mozila/5.0'})    
            html = response.text                                                 
            soup_sub = BeautifulSoup(html, "html.parser")                         

            # separation
            if "entertain" in response.url:                                     
                content = soup_sub.select_one("#articeBody")                        
            elif "sports" in response.url:                                        
                content = soup_sub.select_one("#newsEndContents")             

                # delete unnecessary elements
                divs = content.select("div")
                for div in divs:
                    div.decompose()

                paragraphs = content.select("p")
                for p in paragraphs:
                    p.decompose()

            else:
                content = soup_sub.select_one("#dic_area")                         
            print("========BODY========\n", content.text.strip())
            total_content += content.text.strip()
            article_num += 1
            time.sleep(0.3)

    is_last_page = soup.select_one("a.btn_next").attrs["aria-disabled"]
    if is_last_page == "true":
        print("last page")
        break

    page_num += 1

print(f"{article_num} articles 크롤링 완료")
pyperclip.copy(total_content)
pyautogui.alert('클립보드에 복사되었습니다.')
